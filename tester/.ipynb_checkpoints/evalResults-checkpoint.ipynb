# %%
from os import listdir
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import ast # parse dictionaries from strings

# %matplotlib notebook

# %%
resultStrs = []
for res in listdir('results'):
    resultStrs.append( open('results/' + res) )

results = [ast.literal_eval(res.read()) for res in resultStrs]

# %%
compdata = [{'ETCD Test {}'.format(str(i + 1)) : np.array(results[  2*i  ]['resps'][1:]), 
             'ZK Test {}'.format(str(i + 1)) : np.random.choice(np.array(results[2*i + 1]['resps'][1:]), len(results[  2*i  ]['resps'][1:]), replace=False)}
             for i in range(4)]

# %%
# %matplotlib notebook
dataframes = [pd.DataFrame(d) for d in compdata]


fig, axes = plt.subplots(nrows=2, ncols=2, sharey='row')

fig.suptitle("Response Times", fontsize=20)

grid = [1,1,1,1]
grid[0] = dataframes[0].boxplot(ax=axes[0,0], whis=3)
grid[1] = dataframes[1].boxplot(ax=axes[0,1], whis=3)
grid[2] = dataframes[2].boxplot(ax=axes[1,0], whis=3)
grid[3] = dataframes[3].boxplot(ax=axes[1,1], whis=3)

for p in grid:
    p.set_ylim(0, 0.175)

for p in range(2):
    grid[2*p].set_ylabel('(response times in seconds)')
# Out:
# <img src="data:image/png;base64,..." width="797">

# %%
# %matplotlib notebook
dataframes[0].boxplot(whis=3).set_ylabel('(response times in seconds)')
# Out:
# <img src="data:image/png;base64,..." width="824">
# Text(0,0.5,'(response times in seconds)')

# %%
# %matplotlib notebook
dataframes[1].boxplot(whis=3).set_ylabel('(response times in seconds)')
# Out:
# <img src="data:image/png;base64,..." width="854">
# Text(0,0.5,'(response times in seconds)')

# %%
# %matplotlib notebook
dataframes[2].boxplot(whis=3).set_ylabel('(response times in seconds)')
# Out:
# <img src="data:image/png;base64,..." width="848">
# Text(0,0.5,'(response times in seconds)')

# %%
# %matplotlib notebook
dataframes[3].boxplot(whis=3).set_ylabel('(response times in seconds)')
# Out:
# <img src="data:image/png;base64,..." width="887">
# Text(0,0.5,'(response times in seconds)')

# %%
exp = pd.DataFrame({'time' : np.array(results[7]['resps']), 'logs' : np.array(results[7]['logs']), 'index' : np.array([i for i in range(len(results[7]['resps']))])})
exp.loc[exp['time'] > 0.20]
# Out:
#          time                                               logs  index
# 1    0.224916                                               None      1
# 250  0.805014                                               None    250
# 500  0.234861  Caught Exception: KeeperErrorCode = Connection...    500
# 501  0.681545                                               None    501

# %%
for i in range(21):
    print(str(501-10+i) + '   ' + results[7]['logs'][501-10 + i])
# Out:
# 491   None
# 492   None
# 493   None
# 494   None
# 495   None
# 496   None
# 497   None
# 498   None
# 499   None
# 500   Caught Exception: KeeperErrorCode = ConnectionLoss for /2
# 501   None
# 502   None
# 503   None
# 504   None
# 505   None
# 506   None
# 507   None
# 508   None
# 509   None
# 510   None
# 511   None

# %%
len(results[4]['resps'][1:])
# Out:
# 999

# %%
# %matplotlib notebook


diffs = [len(results[2*i + 1]['resps']) - len(results[  2*i  ]['resps']) for i in range(4)]
print(diffs)
compdata2 = [{'ETCD Test {}'.format(str(i + 1)) : np.array(results[  2*i  ]['resps'][0:len(results[2*i + 1]['resps'])]), 
             'ZK Test {}'.format(str(i + 1)) : np.array(results[2*i + 1]['resps'])}
             for i in range(4)]

dataframes2 = [pd.DataFrame(d) for d in compdata2]


fig, axes = plt.subplots(nrows=2, ncols=2, sharey='row')

grid = [1,1,1,1]
grid[0] = dataframes2[0].plot(ax=axes[0,0])
grid[1] = dataframes2[1].plot(ax=axes[0,1])
grid[2] = dataframes2[2].plot(ax=axes[1,0])
grid[3] = dataframes2[3].plot(ax=axes[1,1])

for p in grid:
    p.set_ylim(0,  1.25)
# Out:
# [0, 0, 0, 0]
# <img src="data:image/png;base64,..." width="874">

# %%
[len(results[i]['resps']) for i in range(8)]
# Out:
# [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]

# %%
a = np.array(results[7]['resps'][0:250])
b = np.array(results[7]['resps'][250:500])
c = np.array(results[7]['resps'][500:750])
d = np.array(results[7]['resps'][750:1000])

inter = np.ravel(np.column_stack((a,b,c,d)))

# %%
# %matplotlib notebook
plt.plot(inter)
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
x = np.array([1,2,3])
x[:100]
# Out:
# array([1, 2, 3])
